# %% [markdown]
# # Universidad Autónoma de Nuevo León
# # Facultad de Ciencias Físico Matemáticas
# # Maestría en Ciencia de Datos
#
# ## Procesamiento y clasificación de datos
#
# ###### Alberto Benavides

# %% [markdown]
# ### Duración del curso

# %% [markdown]
# ![Imagen de WhatsApp 2025-01-06 a las 12.17.14_4922b083.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Clases: 8 de enero a 28 de marzo
# - Entrega de PIAs: 31 al 4 de abril
# - Captura de calificaciones: 7 y 8 de abril
# - Receso de Semana Santa: 17 al 27 de abril

# %% [markdown]
# ### Evaluación
# $$C_\text{tareas} = \sum_i^9 t_i; \{t_i \in \mathbb{N} | 0 \leq t_i \leq 10\}$$
# $$\{C_\text{PIA} \in \mathbb{N} | 0 \leq C_\text{PIA} \leq 15\}$$
#
# $C_\text{participación}$: Puntos extra en cada clase
#
# $$C_\text{final} = \min(100, C_\text{tareas} + C_\text{participación} + C_\text{PIA})$$

# %% [markdown]
# ## Contenido del curso
#
# ### Sesión 1: Análisis de Texto. Introducción
# - Introducción al análisis de texto en Ciencia de Datos
# - Orígenes de datos
# - Preprocesamiento de texto
# - Representación de texto: bolsa de palabras
#
# ### Sesión 2: Análisis de Texto
# - Modelos avanzados de representación de texto
# - Análisis de sentimientos utilizando técnicas de análisis de texto.
#
# ### Sesión 3: Análisis de Texto. Clasificación
# - Aplicaciones de análisis de texto en la clasificación de documentos.
# - Ejemplos prácticos y casos de estudio.
#
# ### Sesión 3.5: Prompt engineering de un LLM
# - Ejemplo de implementación de un LLM con memoria
#
# ### Sesión 4: Análisis de Imágenes
# - Introducción al análisis de imágenes en Ciencia de Datos.
# - Extracción de características y representación de imágenes.
#
# ### Sesión 5: Análisis de Imágenes
# - Redes neuronales convolucionales (CNN) para clasificación de imágenes.
# - Transfer Learning y Fine-tuning en modelos de visión por computadora.
#
# ### Sesión 6: Análisis de Imágenes
# - Aplicaciones de análisis de imágenes: detección de objetos, segmentación semántica.
# - Ejemplos de casos prácticos.
#
# ### Sesión 7: Análisis de Audio
# - Introducción al procesamiento de audio en Ciencia de Datos.
# - Representación de señales de audio
#
# ### Sesión 8: Análisis de Audio
# - Reconocimiento de voz y análisis de habla.
# - Modelos de aprendizaje profundo para procesamiento de audio.
#
# ### Sesión 9: Análisis de Audio
# - Aplicaciones de análisis de audio: identificación de sonidos, clasificación de audio.
# - Ejemplos de aplicación en el mundo real.
#
# ### Sesión 10: Implementación en un Web Service
# - Introducción a la implementación de modelos de Ciencia de Datos en servicios web.
# - Uso de frameworks como Flask para construir un servicio web.
#
# ### Sesión 11: Entrega de proyecto final.

# %% [markdown]
# ## Sesión 1. Análisis de texto. Introducción
#
# ---
#
#
#
# ### Definición de Análisis de Texto
# El análisis de texto es una rama de la ciencia de datos que se centra en la extracción de información útil y significativa a partir de datos de texto no estructurados.
#
# ### Importancia del Análisis de Texto
# Permite obtener conocimientos a partir de grandes volúmenes de texto, como redes sociales, documentos empresariales, correos electrónicos, etc.
# Facilita la automatización de tareas como la clasificación de documentos, el análisis de sentimientos y la extracción de información.

# %% [markdown]
# ### Aplicaciones del Análisis de Texto
#
# #### Aplicaciones Principales
# - Clasificación de documentos
# - Análisis de sentimientos
# - Extracción de información
# - Generación de resúmenes automáticos
# - Traducción automática
# - Chatbots y asistentes virtuales
#
# #### Ejemplos de Casos de Uso
# - Análisis de opiniones en redes sociales para entender la percepción del cliente.
# - Clasificación de correos electrónicos como spam o no spam.
# - Extracción de entidades (nombres, lugares, fechas) de documentos legales.

# %% [markdown]
# ### Componentes del Análisis de Texto
# #### Preprocesamiento de Texto
# - Limpieza de datos: eliminación de signos de puntuación, números, palabras vacías (_stopwords_).
# - Tokenización: dividir el texto en unidades más pequeñas (tokens).
#
# #### Representación de Texto
# - Bolsa de palabras (Bag of Words): representación vectorial basada en la frecuencia de palabras.
# - Modelos de incrustación de palabras (Word Embeddings): representación densa de palabras en un espacio vectorial.

# %% [markdown]
# ### Obtención de datos

# %% [markdown]
# #### Recursos de orígenes de datos
# - Alternativas para obtener fuentes de noticias: https://www.newscatcherapi.com/blog/python-web-scraping-libraries-to-mine-news-data
# - Webscrapper de Reddit: https://github.com/praw-dev/praw
# - Tweets de X: https://www.tweepy.org/
# - Artículos de Wikipedia: https://github.com/goldsmith/Wikipedia

# %%
# https://github.com/raduangelescu/gutenbergpy
# !pip install gutenbergpy

# %%
import gutenbergpy.textget

# %%
def obtener_libro(id = 2701):
    raw_book = gutenbergpy.textget.get_text_by_id(id) # with headers
    clean_book = gutenbergpy.textget.strip_headers(raw_book) # without headers
    return clean_book, raw_book

# %%
libro_limpio, libro = obtener_libro()

# %%
libro[:2000]
# Out:
# b'The Project Gutenberg eBook of Moby-Dick; or The Whale, by Herman Melville\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org. If you are not located in the United States, you\r\nwill have to check the laws of the country where you are located before\r\nusing this eBook.\r\n\r\nTitle: Moby-Dick; or The Whale\r\n\r\nAuthor: Herman Melville\r\n\r\nRelease Date: June, 2001 [eBook #2701]\r\n[Most recently updated: August 18, 2021]\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\nProduced by: Daniel Lazarus, Jonesey, and David Widger\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK MOBY-DICK; OR THE WHALE ***\r\n\r\n\r\n\r\n\r\nMOBY-DICK;\r\n\r\nor, THE WHALE.\r\n\r\nBy Herman Melville\r\n\r\n\r\n\r\nC
# ...

# %%
libro_limpio[:1000]
# Out:
# b'\n\n\n\nMOBY-DICK;\n\nor, THE WHALE.\n\nBy Herman Melville\n\n\n\nCONTENTS\n\nETYMOLOGY.\n\nEXTRACTS (Supplied by a Sub-Sub-Librarian).\n\nCHAPTER 1. Loomings.\n\nCHAPTER 2. The Carpet-Bag.\n\nCHAPTER 3. The Spouter-Inn.\n\nCHAPTER 4. The Counterpane.\n\nCHAPTER 5. Breakfast.\n\nCHAPTER 6. The Street.\n\nCHAPTER 7. The Chapel.\n\nCHAPTER 8. The Pulpit.\n\nCHAPTER 9. The Sermon.\n\nCHAPTER 10. A Bosom Friend.\n\nCHAPTER 11. Nightgown.\n\nCHAPTER 12. Biographical.\n\nCHAPTER 13. Wheelbarrow.\n\nCHAPTER 14. Nantucket.\n\nCHAPTER 15. Chowder.\n\nCHAPTER 16. The Ship.\n\nCHAPTER 17. The Ramadan.\n\nCHAPTER 18. His Mark.\n\nCHAPTER 19. The Prophet.\n\nCHAPTER 20. All Astir.\n\nCHAPTER 21. Going Aboard.\n\nCHAPTER 22. Merry Christmas.\n\nCHAPTER 23. The Lee Shore.\n\nCHAPTER 24. The Advocate.\n\nCHAPTER 25. Postscript.\n\nCHAPTER 26. Knights and Squires.\n\nCHAPTER 27. Knights and Squires.\n\nCHAPTER 28. Ahab.\n\nCHAPTER 29. Enter Ahab; to Him, Stubb.\n\nCHAPTER 30. The Pipe.\n\nCHAPTER 3
# ...

# %%
type(libro_limpio)
# Out:
# bytes

# %%
str_libro = libro_limpio.decode()
str_libro[:1000]
# Out:
# '\n\n\n\nMOBY-DICK;\n\nor, THE WHALE.\n\nBy Herman Melville\n\n\n\nCONTENTS\n\nETYMOLOGY.\n\nEXTRACTS (Supplied by a Sub-Sub-Librarian).\n\nCHAPTER 1. Loomings.\n\nCHAPTER 2. The Carpet-Bag.\n\nCHAPTER 3. The Spouter-Inn.\n\nCHAPTER 4. The Counterpane.\n\nCHAPTER 5. Breakfast.\n\nCHAPTER 6. The Street.\n\nCHAPTER 7. The Chapel.\n\nCHAPTER 8. The Pulpit.\n\nCHAPTER 9. The Sermon.\n\nCHAPTER 10. A Bosom Friend.\n\nCHAPTER 11. Nightgown.\n\nCHAPTER 12. Biographical.\n\nCHAPTER 13. Wheelbarrow.\n\nCHAPTER 14. Nantucket.\n\nCHAPTER 15. Chowder.\n\nCHAPTER 16. The Ship.\n\nCHAPTER 17. The Ramadan.\n\nCHAPTER 18. His Mark.\n\nCHAPTER 19. The Prophet.\n\nCHAPTER 20. All Astir.\n\nCHAPTER 21. Going Aboard.\n\nCHAPTER 22. Merry Christmas.\n\nCHAPTER 23. The Lee Shore.\n\nCHAPTER 24. The Advocate.\n\nCHAPTER 25. Postscript.\n\nCHAPTER 26. Knights and Squires.\n\nCHAPTER 27. Knights and Squires.\n\nCHAPTER 28. Ahab.\n\nCHAPTER 29. Enter Ahab; to Him, Stubb.\n\nCHAPTER 30. The Pipe.\n\nCHAPTER 31
# ...

# %%
list_libro = str_libro.split("\n")
list_libro[:20]
# Out:
# ['',
#  '',
#  '',
#  '',
#  'MOBY-DICK;',
#  '',
#  'or, THE WHALE.',
#  '',
#  'By Herman Melville',
#  '',
#  '',
#  '',
#  'CONTENTS',
#  '',
#  'ETYMOLOGY.',
#  '',
#  'EXTRACTS (Supplied by a Sub-Sub-Librarian).',
#  '',
#  'CHAPTER 1. Loomings.',
#  '']

# %%
libro_filitrado = list(filter(None, list_libro))
libro_filitrado[:20]
# Out:
# ['MOBY-DICK;',
#  'or, THE WHALE.',
#  'By Herman Melville',
#  'CONTENTS',
#  'ETYMOLOGY.',
#  'EXTRACTS (Supplied by a Sub-Sub-Librarian).',
#  'CHAPTER 1. Loomings.',
#  'CHAPTER 2. The Carpet-Bag.',
#  'CHAPTER 3. The Spouter-Inn.',
#  'CHAPTER 4. The Counterpane.',
#  'CHAPTER 5. Breakfast.',
#  'CHAPTER 6. The Street.',
#  'CHAPTER 7. The Chapel.',
#  'CHAPTER 8. The Pulpit.',
#  'CHAPTER 9. The Sermon.',
#  'CHAPTER 10. A Bosom Friend.',
#  'CHAPTER 11. Nightgown.',
#  'CHAPTER 12. Biographical.',
#  'CHAPTER 13. Wheelbarrow.',
#  'CHAPTER 14. Nantucket.']

# %% [markdown]
# ### Preprocesamiento

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
texto = "¡Este es un ejemplo de preprocesamiento de texto en Python!"

# Eliminar signos de puntuación y convertir a minúsculas
texto_limpio = re.sub(r'[^\w\s]', '', texto.lower())

texto_limpio
# Out:
# 'este es un ejemplo de preprocesamiento de texto en python'

# %%
# Eliminar stopwords
stop_words = set(stopwords.words('spanish'))
list(stop_words)[:20]
# Out:
# ['tenido',
#  'en',
#  'tuvimos',
#  'su',
#  'como',
#  'tuyo',
#  'estaba',
#  'sí',
#  'cuando',
#  'tuvieron',
#  'estaremos',
#  'quien',
#  'quienes',
#  'hemos',
#  'fui',
#  'serían',
#  'tenéis',
#  'habían',
#  'qué',
#  'vuestra']

# %%
tokens = word_tokenize(texto_limpio)
tokens
# Out:
# ['este',
#  'es',
#  'un',
#  'ejemplo',
#  'de',
#  'preprocesamiento',
#  'de',
#  'texto',
#  'en',
#  'python']

# %%
t = "no era el más honesto no el más piadoso pero era un hombre valiente."
tokens = word_tokenize(t)
texto_filtrado = [word for word in tokens if word not in stop_words]

texto_filtrado
# Out:
# ['honesto', 'piadoso', 'hombre', 'valiente', '.']

# %%
stop_words.add('ejemplo')

texto_filtrado = [word for word in tokens if word not in stop_words]

texto_filtrado
# Out:
# ['honesto', 'piadoso', 'hombre', 'valiente', '.']

# %%
def tokens(txt, idioma = 'english'):
    texto_limpio = re.sub(r'[^\w\s]', '', txt.lower())

    stop_words = set(stopwords.words(idioma))
    tokens = word_tokenize(texto_limpio)
    texto_filtrado = [word for word in tokens if word not in stop_words]
    return texto_filtrado

# %%
map_libro = list(map(tokens, libro_filitrado))

# %%
# Inicio del libro
map_libro[151:300]
# Out:
# [['etymology'],
#  ['supplied', 'late', 'consumptive', 'usher', 'grammar', 'school'],
#  ['pale', 'usherthreadbare', 'coat', 'heart', 'body', 'brain', 'see'],
#  ['ever', 'dusting', 'old', 'lexicons', 'grammars', 'queer'],
#  ['handkerchief', 'mockingly', 'embellished', 'gay', 'flags'],
#  ['known', 'nations', 'world', 'loved', 'dust', 'old', 'grammars'],
#  ['somehow', 'mildly', 'reminded', 'mortality'],
#  ['take', 'hand', 'school', 'others', 'teach'],
#  ['name', 'whalefish', 'called', 'tongue', 'leaving'],
#  ['ignorance', 'letter', 'h', 'almost', 'alone', 'maketh'],
#  ['signification', 'word', 'deliver', 'true'],
#  ['_hackluyt_'],
#  ['whale', 'sw', 'dan', '_hval_', 'animal', 'named'],
#  ['roundness', 'rolling', 'dan', '_hvalt_', 'arched', 'vaulted'],
#  ['_websters', 'dictionary_'],
#  ['whale', 'immediately', 'dut', 'ger', '_wallen_'],
#  ['_walwian_', 'roll', 'wallow', '_richardsons', 'dictionary_'],
#  ['חו', '_hebrew_'],
#  ['ϰητος', '_greek_'],
#  ['cetus', '_latin_'],
# ...

# %%
map_libro[-100:]
# Out:
# [['drawers', 'mouldy', 'salted', 'death', 'thoughcherries'],
#  ['cherries', 'cherries', 'oh', 'flask', 'one', 'red', 'cherry', 'ere', 'die'],
#  ['cherries', 'wish', 'grow', 'oh', 'stubb', 'hope'],
#  ['poor', 'mothers', 'drawn', 'partpay', 'ere', 'coppers'],
#  ['come', 'voyage'],
#  ['ships', 'bows', 'nearly', 'seamen', 'hung', 'inactive', 'hammers'],
#  ['bits', 'plank', 'lances', 'harpoons', 'mechanically', 'retained'],
#  ['hands', 'darted', 'various', 'employments'],
#  ['enchanted', 'eyes', 'intent', 'upon', 'whale', 'side', 'side'],
#  ['strangely', 'vibrating', 'predestinating', 'head', 'sent', 'broad', 'band'],
#  ['overspreading', 'semicircular', 'foam', 'rushed', 'retribution'],
#  ['swift', 'vengeance', 'eternal', 'malice', 'whole', 'aspect', 'spite'],
#  ['mortal', 'man', 'could', 'solid', 'white', 'buttress', 'forehead'],
#  ['smote',
#   'ships',
#   'starboard',
#   'bow',
#   'till',
#   'men',
#   'timbers',
#   'reeled',
#   'fell'],
# ...

# %% [markdown]
# ### Tokenización

# %%
tokens = []
for token in map_libro:
    tokens.extend(token)
tokens[:20]
# Out:
# ['mobydick',
#  'whale',
#  'herman',
#  'melville',
#  'contents',
#  'etymology',
#  'extracts',
#  'supplied',
#  'subsublibrarian',
#  'chapter',
#  '1',
#  'loomings',
#  'chapter',
#  '2',
#  'carpetbag',
#  'chapter',
#  '3',
#  'spouterinn',
#  'chapter',
#  '4']

# %%
import pandas as pd

# %%
df = pd.DataFrame(tokens)
df
# Out:
#                0
# 0       mobydick
# 1          whale
# 2         herman
# 3       melville
# 4       contents
# ...          ...
# 109366   missing
# 109367  children
# 109368     found
# 109369   another
# 109370    orphan
#
# [109371 rows x 1 columns]

# %% [markdown]
# ### Conteo de frecuencias

# %%
# Conteo de frecuencias
conteo_frecuencias = df.value_counts()
conteo_frecuencias
# Out:
# 0
# whale        950
# one          890
# like         575
# upon         565
# old          440
#             ...
# comets         1
# mothered       1
# motherit       1
# cometheir      1
# חו             1
# Name: count, Length: 20135, dtype: int64

# %%
df_frecuencias = conteo_frecuencias.to_frame()
df_frecuencias
# Out:
#            count
# 0
# whale        950
# one          890
# like         575
# upon         565
# old          440
# ...          ...
# comets         1
# mothered       1
# motherit       1
# cometheir      1
# חו             1
#
# [20135 rows x 1 columns]

# %%
df_frecuencias.reset_index(inplace = True)
df_frecuencias.columns = ['token', 'conteo']
df_frecuencias
# Out:
#            token  conteo
# 0          whale     950
# 1            one     890
# 2           like     575
# 3           upon     565
# 4            old     440
# ...          ...     ...
# 20130     comets       1
# 20131   mothered       1
# 20132   motherit       1
# 20133  cometheir       1
# 20134         חו       1
#
# [20135 rows x 2 columns]

# %%
df_frecuencias.head(20)
# Out:
#       token  conteo
# 0     whale     950
# 1       one     890
# 2      like     575
# 3      upon     565
# 4       old     440
# 5       man     435
# 6     would     427
# 7        ye     420
# 8      ahab     416
# 9    whales     396
# 10     ship     384
# 11      sea     379
# 12   though     364
# 13      yet     339
# 14     time     323
# 15     long     313
# 16  chapter     308
# 17    still     307
# 18    great     305
# 19     said     294

# %% [markdown]
# - [ ] Eliminar palabras vacías (_stop words_)
# - [x] Eliminar desinencias

# %% [markdown]
# ### Eliminación de desinencias ([_stemming_](https://www.nltk.org/howto/stem.html))
#
# [RAE](https://dle.rae.es/desinencia): Morfema flexivo pospuesto a la raíz, especialmente la de un verbo.
#
# >¿Cuál es la raíz de las siguientes palabras? <br>
# Correr, corríamos, corran, correrán, corrieran, corriendo.
#
# > ¿Cuáles son las desinencias?
#
# Características:
# - Simplifica
# - Método rápido
# - **No toma en cuenta la gramática**
#
# Hay diferentes algoritmos para hacer _stemming_, el más común por lo sencillo es [PorterStemmer](https://tartarus.org/martin/PorterStemmer/python.txt).

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

texto = "running runs runner runners"

palabras = word_tokenize(texto)

stemmed_words = [ps.stem(palabra) for palabra in palabras]
stemmed_words
# Out:
# ['run', 'run', 'runner', 'runner']

# %% [markdown]
# Otros son más agresivos.

# %%
from nltk.stem import LancasterStemmer

ls = LancasterStemmer()

stemmed_words = [ls.stem(palabra) for palabra in palabras]
stemmed_words
# Out:
# ['run', 'run', 'run', 'run']

# %% [markdown]
# #### _Stemming_ en español (entre otros idiomas)
#
# El paquete `nltk` contiene [SnowballStemmer](https://www.nltk.org/api/nltk.stem.SnowballStemmer.html), que permite convservar las raíces de otros idiomas.

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("spanish")

texto = 'son las seis de la mañana y me da igual \
voy a salir a la calle, voy a ponerme a gritar \
voy a gritar que te quiero, que te quiero de verdad \
con esa sonrisa puesta, de verdad que no me cuesta \
pensar en ti cuando me acuesto \
pero, Aitana, no imagines el resto \
que si no, no queda bonito esto.'

palabras = word_tokenize(texto)

stemmed_words = [stemmer.stem(palabra) for palabra in palabras]
stemmed_words # ¡SAL NO ES LO MISMO QUE SALIR!
# Out:
# ['son',
#  'las',
#  'seis',
#  'de',
#  'la',
#  'mañan',
#  'y',
#  'me',
#  'da',
#  'igual',
#  'voy',
#  'a',
#  'sal',
#  'a',
#  'la',
#  'call',
#  ',',
#  'voy',
#  'a',
#  'pon',
#  'a',
#  'grit',
#  'voy',
#  'a',
#  'grit',
#  'que',
#  'te',
#  'quier',
#  ',',
#  'que',
#  'te',
#  'quier',
#  'de',
#  'verd',
#  'con',
#  'esa',
#  'sonris',
#  'puest',
#  ',',
#  'de',
#  'verd',
#  'que',
#  'no',
#  'me',
#  'cuest',
#  'pens',
#  'en',
#  'ti',
#  'cuand',
#  'me',
#  'acuest',
#  'per',
#  ',',
#  'aitan',
#  ',',
#  'no',
#  'imagin',
#  'el',
#  'rest',
#  'que',
#  'si',
#  'no',
#  ',',
#  'no',
#  'qued',
#  'bonit',
#  'esto',
#  '.']

# %% [markdown]
# ### Lematización, o cuando la gramática importa

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

text = "better studies children happily wolves flying doing swimming ate corpora alumni"

palabras = word_tokenize(text)

stemmed_words = [ps.stem(palabra) for palabra in palabras]
stemmed_words
# Out:
# ['better',
#  'studi',
#  'children',
#  'happili',
#  'wolv',
#  'fli',
#  'do',
#  'swim',
#  'ate',
#  'corpora',
#  'alumni']

# %%
lemmatized_words = [lemmatizer.lemmatize(palabra) for palabra in palabras]
lemmatized_words
# Out:
# ['better',
#  'study',
#  'child',
#  'happily',
#  'wolf',
#  'flying',
#  'doing',
#  'swimming',
#  'ate',
#  'corpus',
#  'alumnus']

# %%
# Diferenciar adjetivos, verbos, adverbios...
lemmatized_words = [lemmatizer.lemmatize(palabra, pos = 'a') for palabra in palabras]
lemmatized_words
# Out:
# ['good',
#  'studies',
#  'children',
#  'happily',
#  'wolves',
#  'flying',
#  'doing',
#  'swimming',
#  'ate',
#  'corpora',
#  'alumni']

# %%
lemmatized_words = [lemmatizer.lemmatize(palabra, pos = 'v') for palabra in palabras]
lemmatized_words
# Out:
# ['better',
#  'study',
#  'children',
#  'happily',
#  'wolves',
#  'fly',
#  'do',
#  'swim',
#  'eat',
#  'corpora',
#  'alumni']

# %% [markdown]
# En español pasa algo similar.

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 52.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("es_core_news_sm")
palabras = [
    "corriendo", "mejor", "niños", "rápidamente",
    "lobos", "fui", "jugando", "comió", "dormido", "felices"
]

stemming_resultados = [stemmer.stem(palabra) for palabra in palabras]

doc = nlp(" ".join(palabras))
lematizacion_resultados = [token.lemma_ for token in doc]

df_comparacion = pd.DataFrame({
    "Palabra Original": palabras,
    "Stemming (Snowball)": stemming_resultados,
    "Lematización (spaCy)": lematizacion_resultados
})

df_comparacion
# Out:
#   Palabra Original Stemming (Snowball) Lematización (spaCy)
# 0        corriendo                corr               correr
# 1            mejor               mejor                mejor
# 2            niños                 niñ                 niño
# 3      rápidamente               rapid          rápidamente
# 4            lobos                 lob                lobos
# 5              fui                 fui                   ir
# 6          jugando                 jug                jugar
# 7            comió                 com                comer
# 8          dormido                dorm              dormido
# 9          felices               felic                feliz

# %%
# !python -m spacy download es_core_news_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.0/568.0 MB 1.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("es_core_news_lg")

doc = nlp(" ".join(palabras))
lematizacion_resultados = [token.lemma_ for token in doc]
lematizacion_resultados
# Out:
# ['correr',
#  'mejor',
#  'niño',
#  'rápidamente',
#  'lobo',
#  'ir',
#  'jugar',
#  'comer',
#  'dormido',
#  'felices']

# %% [markdown]
# ### Representación gráfica

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df_frecuencias.iloc[:10].token, df_frecuencias.iloc[:10].conteo)
# Out:
# <BarContainer object of 10 artists>

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud().generate(' '.join(tokens))

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# #### n-Gramas

# %%
from nltk import ngrams

# %%
frase = 'eso eso eso es todo amigos'

n = 2 # un bigrama
bigramas = ngrams(frase.split(), n)
for gramas in bigramas:
    print (gramas)
# Out:
# ('eso', 'eso')
# ('eso', 'eso')
# ('eso', 'es')
# ('es', 'todo')
# ('todo', 'amigos')

# %%
import networkx as nx

lsita_bigramas = list(ngrams(frase.split(), n))

G = nx.DiGraph()

for gram in lsita_bigramas:
    G.add_edge(gram[0], gram[1])

plt.figure(figsize=(10, 6))
nx.draw(G, with_labels=True, node_size=3000, font_size=14)
plt.title("Grafo de Bigramas")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Guía rápida de Markdown
#
# # Título nivel 1
# ## Título nivel 2
# ...
# ##### Título nivel 5
#
# Tenemos texto que se puede poner en **negritas**, _cursivas_, ~tachado~, <span style="color:red">esto está en rojo</span>
#
# - lista
# - elemento
#
# 1. numerada
# 1. no importa qué número le ponga
# 14. siempre va a seguir los números naturales
#
# - [ ] Tareas
# - [x] Tarea terminada
#
# 🥳🥳🥳
#
# [texto del link](google.com)
#
# ![texto alternativo](https://www.freecodecamp.org/news/content/images/size/w2000/2021/09/Cssfontcolor.png)
#
# <center>
#
# columna 1 | columna 2 | columna 3
# :--- | :---: | ---:
# a | b | c
#
# </center>

# %% [markdown]
# #### Prerrequisitos
#
# Crear un repositorio público y subir el link en el archivo de Excel correspondiente proporcionado por el tutor.

# %% [markdown]
# ---

# %% [markdown]
# ### Participación (2 puntos)
#
# Una de dos:
#
# - Aplicar la técnica de _stem_ o lematización para analizar la frecuencia de palabras de esta obra
# - Implementar una manera de obtener la frecuencia de $n$-gramas de cualquier obra antes de que se acabe la clase. Subir la solución propuesta al repositorio

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.util import ngrams

# Descargar recursos necesarios de NLTK
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')



def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    return text

def analyze_word_frequency(text, method="lemmatization"):
    text = clean_text(text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [t for t in tokens if t not in stop_words]

    if method == "lemmatization":
        lemmatizer = WordNetLemmatizer()
        processed_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    elif method == "stemming":
        stemmer = nltk.PorterStemmer()
        processed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    else:
        raise ValueError("Method must be either 'lemmatization' or 'stemming'")

    word_freq = Counter(processed_tokens)
    return word_freq

def analyze_ngram_frequency(text, n=2):
    text = clean_text(text)
    tokens = word_tokenize(text)
    n_grams = list(ngrams(tokens, n))
    ngram_freq = Counter(n_grams)
    return ngram_freq

word_frequency = analyze_word_frequency(str_libro, method="lemmatization")

bigram_frequency = analyze_ngram_frequency(str_libro, n=2)

print("Frecuencia de palabras (Top 10):")
print(word_frequency.most_common(10))

print("\nFrecuencia de bigramas (Top 10):")
print(bigram_frequency.most_common(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Frecuencia de palabras (Top 10):
# [('whale', 1346), ('one', 919), ('like', 578), ('upon', 565), ('ship', 538), ('ahab', 493), ('man', 486), ('sea', 466), ('old', 440), ('time', 432)]
#
# Frecuencia de bigramas (Top 10):
# [(('of', 'the'), 1885), (('in', 'the'), 1177), (('to', 'the'), 729), (('from', 'the'), 441), (('of', 'his'), 372), (('and', 'the'), 369), (('on', 'the'), 356), (('of', 'a'), 333), (('at', 'the'), 329), (('to', 'be'), 327)]

# %% [markdown]
# ---

# %% [markdown]
# ### Tarea (10 puntos)
#
# #### Requisitos
#
# - Realizar un análisis estadístico sobre algún origen de datos textual (libros, publicaciones en redes sociales, entradas de blog, discursos políticos...) sobre dos o más fuentes de uno o más autores.
#
# - Analizar estadística descriptiva básica, frecuencias, distribuciones de palabras, n-gramas, uso de signos de puntuación, emojis...
#
# - Comparar las diversas fuentes y aventurar conclusiones a partir de los hallazgos en un reporte científico (de preferencia hecho en Latex; si no en Markdown como `readme.md` del repositorio).
#
# - Sube a tu repositorio el código utilizado en tu tarea y el reporte en PDF (y TEX si aplica) en una carpeta claramente identificada.
#
# #### Calificación
#
# Se califica con 10 puntos quien cumple con los requisitos.

# %% [markdown]
# ## Referencias
#
# - Bird, S., Klein, E., & Loper, E. (2009). Natural Language Processing with Python. O'Reilly Media.
# - Manning, C. D., & Schütze, H. (1999). Foundations of Statistical Natural Language Processing. MIT Press.
# - Jurafsky, D., & Martin, J. H. (2019). Speech and Language Processing. Pearson Education.
# - https://www.tidytextmining.com/
